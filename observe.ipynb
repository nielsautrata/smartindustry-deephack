# %%
import plotly.express as px
import numpy as np
global_pcd = np.load("pcd.npy")
X = global_pcd[:,3:]
fig = px.scatter_3d(x=X[:,0], y=X[:, 1], z=X[:, 2])
fig.show()
# Out:
# <div>                            <div id="a9c1263c-d606-4904-9b0d-342efd0791f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9c1263c-d606-4904-9b0d-342efd0791f1")) {                    Plotly.newPlot(                        "a9c1263c-d606-4904-9b0d-342efd0791f1",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<br>z=%{z}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[269.0,270.0,271.0,272.0,273.0,274.0,275.0,256.0,257.0,258.0,259.0,260.0,261.0,262.0,263.0,264.0,265.0,266.0,267.0,268.0,269.0,270.0,271.0,272.0,273.0,274.0,275.0,276.0,277.0,278.0,279.0,247.0,248.0,249.0,250.0,251.0,252.0,253.0,254.0,255.0,256.0,257.0,258.0,259.0,260.0,261.0
# ...
